# %%
import matplotlib.pyplot as plt

import Framework.Confounder_Injection as CI
import Framework.Models as Models
import importlib
importlib.reload(Models)
importlib.reload(CI)
import torch
import pandas as pd
import numpy as np
import seaborn as sbs
import matplotlib.pyplot as plt
import time

# %%
params = [
    [[1, 4], [3, 6]], # real feature
    [[10, 12], [20, 22]] # confounder
]
hyper_params = {'lr':0.01, 'weight_decay':0.0001}

# %% [markdown]
# # De-correlated confounders in target- and test-data

# %% [markdown]
# ### alpha=0.1

# %%
c = CI.confounder()
model = Models.Br_Net_DANN(alpha=0.1)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=500, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)

# %% [markdown]
# ### alpha=0.2

# %%
c = CI.confounder()
model = Models.Br_Net_DANN(alpha=0.2)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=500, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       2 model = Models.Br_Net_DANN(alpha=0.2)
#       3 c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
# ----> 4 c.train(model=model, epochs=500, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
#       5 c.plot(accuracy_vs_epoch=True)
#
# File ~/Bachelor Arbeit/Jupyter/Confounder_Injection/Framework/Confounder_Injection.py:620, in confounder.train(self, model, epochs, device, optimizer, loss_fn, batch_size, hyper_params)
#     618 self.train_dataloader = create_dataloader(self.train_x[set],self.train_y[set], domain=self.train_domain_labels[set], confounder=self.train_confounder_labels[set], batch_size=batch_size).get_dataloader()
#     619 t = train(self.mode, self.model, self.train_dataloader, device, model_optimizer, loss_fn)
# --> 620 t.run()
#     622 for cf_var in range(0,len(self.index)):
#     623     test_dataloader = create_dataloader(self.test_x[cf_var],self.test_y[cf_var], domain=self.test_domain_labels[cf_var], confounder=self.test_confounder_labels[cf_var], batch_size=batch_size).get_dataloader()
#
# File ~/Bachelor Arbeit/Jupyter/Confounder_Injection/Framework/Confounder_Injection.py:498, in train.run(self)
#     496 def run(self):
#     497     if isinstance(self.model, Models.SimpleConv_DANN) or isinstance(self.model, Models.Br_Net_DANN):
# --> 498         self.train_adversarial(mode="DANN")
#     500     elif isinstance(self.model, Models.SimpleConv_CF_free) or isinstance(self.model, Models.Br_Net_CF_free):
#     501         self.train_adversarial(mode="CF_free")
#
# File ~/Bachelor Arbeit/Jupyter/Confounder_Injection/Framework/Confounder_Injection.py:491, in train.train_adversarial(self, mode, ignore)
#     489     # Backpropagation
#     490     self.optimizer.zero_grad()
# --> 491     loss.backward()
#     493     self.optimizer.step()
#     494 return
#
# File ~/anaconda3/envs/confounder_3.10/lib/python3.10/site-packages/torch/_tensor.py:363, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     354 if has_torch_function_unary(self):
#     355     return handle_torch_function(
#     356         Tensor.backward,
#     357         (self,),
#    (...)
#     361         create_graph=create_graph,
#     362         inputs=inputs)
# --> 363 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/anaconda3/envs/confounder_3.10/lib/python3.10/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# ### alpha=0.3

# %%
c = CI.confounder()
model = Models.Br_Net_DANN(alpha=0.3)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=500, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)

# %% [markdown]
# ### alpha=0.5

# %%
c = CI.confounder()
model = Models.Br_Net_DANN(alpha=0.5)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=500, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)

# %% [markdown]
# ### alpha=0.7

# %%
c = CI.confounder()
model = Models.Br_Net_DANN(alpha=0.7)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=500, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)

# %% [markdown]
# ### alpha=1

# %%
c = CI.confounder()
model = Models.Br_Net_DANN(alpha=1)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=500, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)
