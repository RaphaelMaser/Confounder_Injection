# %%
import matplotlib.pyplot as plt

import Framework.Confounder_Injection as CI
import Framework.Models as Models
import importlib
importlib.reload(Models)
importlib.reload(CI)
import torch
import pandas as pd
import numpy as np
import seaborn as sbs
import matplotlib.pyplot as plt
import time

# %%
params = [
    [[1, 4], [3, 6]], # real feature
    [[10, 12], [20, 22]] # confounder
]
hyper_params = {'lr':0.01, 'weight_decay':0.0001}

# %%
epochs = 500
t = time.time()

# %% [markdown]
# # De-correlated confounders in target- and test-data

# %% [markdown]
# ### alpha=0.1

# %%
c = CI.confounder(start_timer=True)
model = Models.Br_Net_CF_free(alpha=0.1)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True, conditioning=0)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)

# %% [markdown]
# ### alpha=0.2

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=0.2)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True, conditioning=0)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 4>()
#       2 model = Models.Br_Net_CF_free(alpha=0.2)
#       3 c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True, conditioning=0)
# ----> 4 c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
#       5 c.plot(accuracy_vs_epoch=True)
#
# File ~/Bachelor Arbeit/Jupyter/Confounder_Injection/Framework/Confounder_Injection.py:624, in confounder.train(self, model, epochs, device, optimizer, loss_fn, batch_size, hyper_params)
#     622 for cf_var in range(0,len(self.index)):
# ...

# %% [markdown]
# ### alpha=0.3

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=0.3)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True, conditioning=0)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)

# %% [markdown]
# ### alpha=0.5

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=0.5)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True, conditioning=0)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)

# %% [markdown]
# ### alpha=0.7

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=0.7)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True, conditioning=0)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)

# %% [markdown]
# ### alpha=0.85

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=0.85)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True, conditioning=0)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)

# %% [markdown]
# ### alpha=1

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=1)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True, conditioning=0)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params=hyper_params)
c.plot(accuracy_vs_epoch=True)

# %%
c.show_time()
