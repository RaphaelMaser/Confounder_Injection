# %%
import matplotlib.pyplot as plt

import Framework.Confounder_Injection as CI
import Framework.Models as Models
import importlib
importlib.reload(Models)
importlib.reload(CI)
import torch
import pandas as pd
import numpy as np
import seaborn as sbs
import matplotlib.pyplot as plt
import time

# %%
params = [
    [[1, 4], [3, 6]], # real feature
    [[10, 12], [20, 22]] # confounder
]

# %% [markdown]
# # De-correlated confounders in target- and test-data

# %%
epochs = 500

# %% [markdown]
# ### alpha=0.1

# %%
c = CI.confounder(start_timer=True)
model = Models.Br_Net_CF_free(alpha=0.1)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params={'lr':0.001})
c.plot(accuracy_vs_epoch=True)
# Out:
# CUDA detected

# %% [markdown]
# ### alpha=0.2

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=0.2)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params={'lr':0.001})
c.plot(accuracy_vs_epoch=True)
# Out:
# CUDA detected

# %% [markdown]
# ### alpha=0.3

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=0.3)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params={'lr':0.001})
c.plot(accuracy_vs_epoch=True)
# Out:
# CUDA detected
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_234328/3678421949.py in <module>
#       2 model = Models.Br_Net_CF_free(alpha=0.3)
#       3 c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
# ----> 4 c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params={'lr':0.001})
#       5 c.plot(accuracy_vs_epoch=True)
#
# /mnt/irisgpfs/users/rmaser/bachelor_thesis/Confounder_Injection/Framework/Confounder_Injection.py in train(self, model, epochs, device, optimizer, loss_fn, batch_size, hyper_params)
#     620                 self.test_dataloader = create_dataloader(self.test_x[set],self.test_y[set], domain=self.test_domain_labels[set], confounder=self.test_confounder_labels[set], batch_size=batch_size).get_dataloader()
#     621                 t = train(self.mode, self.model, self.test_dataloader, self.train_dataloader, device, model_optimizer, loss_fn)
# --> 622                 classification_accuracy, confounder_accuracy = t.run()
#     623                 #epoch_acc[i] = results
#     624
#
# /mnt/irisgpfs/users/rmaser/bachelor_thesis/Confounder_Injection/Framework/Confounder_Injection.py in run(self)
#     501
#     502         elif isinstance(self.model, Models.SimpleConv_CF_free) or isinstance(self.model, Models.Br_Net_CF_free):
# --> 503             self.train_adversarial(mode="CF_free")
#     504             accuracy, loss = self.test()
#     505         else:
#
# /mnt/irisgpfs/users/rmaser/bachelor_thesis/Confounder_Injection/Framework/Confounder_Injection.py in train_adversarial(self, mode, ignore)
#     481
#     482             # prediction
# --> 483             class_pred, conf_pred = self.model(X)
#     484
#     485             # compute error
#
# ~/.conda/envs/confounder_injection/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /mnt/irisgpfs/users/rmaser/bachelor_thesis/Confounder_Injection/Framework/Models.py in forward(self, x)
#     143
#     144     def forward(self, x):
# --> 145         features = self.linear_relu_stack(x)
#     146         reverse_features = GradientReversal.apply(features, self.alpha)
#     147
#
# ~/.conda/envs/confounder_injection/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.conda/envs/confounder_injection/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/.conda/envs/confounder_injection/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.conda/envs/confounder_injection/lib/python3.9/site-packages/torch/nn/modules/activation.py in forward(self, input)
#     347
#     348     def forward(self, input: Tensor) -> Tensor:
# --> 349         return torch.tanh(input)
#     350
#     351 class SiLU(Module):
#
# KeyboardInterrupt:

# %% [markdown]
# ### alpha=0.5

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=0.5)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params={'lr':0.001})
c.plot(accuracy_vs_epoch=True)

# %% [markdown]
# ### alpha=0.7

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=0.7)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params={'lr':0.001})
c.plot(accuracy_vs_epoch=True)

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=0.85)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params={'lr':0.001})
c.plot(accuracy_vs_epoch=True)

# %% [markdown]
# ### alpha=1

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=1)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params={'lr':0.001})
c.plot(accuracy_vs_epoch=True)

# %%
### alpha=1.5

# %%
c = CI.confounder()
model = Models.Br_Net_CF_free(alpha=1.5)
c.generate_data(mode="br_net", samples=512, overlap=0, target_domain_samples=16, target_domain_confounding=1, train_confounding=1, test_confounding=np.arange(0, 1.01, 0.5), params=params, de_correlate_confounder_test=True, de_correlate_confounder_target=True)
c.train(model=model, epochs=epochs, batch_size=64, optimizer=torch.optim.Adam, hyper_params={'lr':0.001})
c.plot(accuracy_vs_epoch=True)

# %%
c.show_time()
