# %%
import wandb

import Framework.Confounder_Injection as CI
import Framework.Models as Models
import importlib
importlib.reload(Models)
importlib.reload(CI)
import torch
import time
import pandas as pd
import pathlib
import ast

# %% [markdown]
# In "Validation of synthetic data" the case were the training_data was completely confounded was tested to show that neural networks indeed fit to confounding factors in images. Now the hypothesis is that if we have a small set of unconfounded data we can either use a confounder-free neural network or a DANN to unlearn the confounders. For establishing a performance baseline we need to test the SimpleConv on a dataset consisting of the confounded set and the small unconfounded set, otherwise the conditions would not be equal for the different networks.

# %% [markdown]
# # No confounders in target and test_data

# %% [markdown]
# In this case there are 512 samples from the source domain (with correlating confounders) and a varying number of samples (16 or 64) from the target domain (with no confounders).

# %% [markdown]
# In this case the network is able to achieve the highest possible accuracy. When the confounder is absent the network seems to be able to use the real features for distinguishing the classes and when the confounder is present the network can use it to achieve higher accuracy.

# %% [markdown]
# ### With 16 training-samples from target population

# %%
CI.sync_wandb_data("BrNet on br_net data")

# %%
dir = pathlib.Path().resolve()
file = dir / "BrNet on br_net data.json"
p = CI.plot_from_csv()

# %%
config_filter = {"model": "BrNet", "target_domain_samples":16, "de_correlate_confounder_target": False}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %%
config_filter = {"model": "BrNet_CF_free", "target_domain_samples":16, "de_correlate_confounder_target": False}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %%
config_filter = {"model": "BrNet_CF_free_conditioned0", "target_domain_samples":16, "de_correlate_confounder_target": False}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %%
config_filter = {"model": "BrNet_DANN", "target_domain_samples":16, "de_correlate_confounder_target": False}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %% [markdown]
# The accuracy with more samples is the same but the network converges faster.

# %%
config_filter = {"confounder_strength":0, "target_domain_samples":16, "de_correlate_confounder_target": False}
p.accuracy_vs_epoch(file, config_filter, groupby="model")

# %%
config_filter = {"confounder_strength":1, "target_domain_samples":16, "de_correlate_confounder_target": False}
p.accuracy_vs_epoch(file, config_filter, groupby="model")

# %% [markdown]
# # De-correlated confounders in target- and test-data

# %% [markdown]
# In this case there are confounders present in the data from target domain and test-set but they are de-correlated with the real features (they are rather distributed by pure chance). This is more representative of real world examples.

# %% [markdown]
# In this case the SimpleConv's accuracy diminishes when the confounding strength increases, contrary to the case before. Again the network uses the confounder as approximation, if present. But this time the confounder gives wrong clues about the classes and therefore the network's accuracy drops heavily.

# %% [markdown]
# ### With 16 training-samples from target population

# %%
config_filter = {"model": "BrNet", "target_domain_samples":16, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %%
config_filter = {"model": "BrNet_CF_free", "target_domain_samples":16, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %%
config_filter = {"model": "BrNet_CF_free0", "target_domain_samples":16, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %%
config_filter = {"model": "BrNet_DANN", "target_domain_samples":16, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %%
config_filter = {"confounder_strength":0, "target_domain_samples":16, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="model")

# %%
config_filter = {"confounder_strength":1, "target_domain_samples":16, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="model")

# %% [markdown]
# ### With 128 training-samples from target population

# %%
config_filter = {"model": "BrNet", "target_domain_samples":128, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %%
config_filter = {"model": "BrNet_CF_free", "target_domain_samples":128, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %%
config_filter = {"model": "BrNet_CF_free_conditioned0", "target_domain_samples":128, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %%
config_filter = {"model": "BrNet_DANN", "target_domain_samples":128, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="confounder_strength")

# %%
config_filter = {"confounder_strength":0, "target_domain_samples":128, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="model")

# %%
config_filter = {"confounder_strength":0, "target_domain_samples":128, "de_correlate_confounder_target": True}
p.accuracy_vs_epoch(file, config_filter, groupby="model")

# %%
#c.show_time()
